# %% [markdown]
# 1. VARIABLES Y TIPOS DE DATOS
# Tipo        Descripción         Ejemplo
# str         Texto/Cadena        "Hola"
# int         Número entero       42, -5
# float       Número decimal      3.14, -2.5
# bool        Verdadero/Falso     True, False
# list        Lista de elementos  [1, 2, 3]
# dict        Clave-valor         {"a": 1}
# tuple       Tupla (inmutable)   (1, 2, 3)
# set         Conjunto único      {1, 2, 3}
#
# **CONVERSION DE TIPOS**
# x = int("10")      # String a int
# y = str(42)        # int a string
# z = float("3.14")  # String a float
# b = bool(1)        # int a bool
#
#
# 2. OPERADORES
# ARITMETICOS
# Operador    Nombre
# +           Suma
# -           Resta
# *           Multiplicación
# /           División
# //          División entera
# %           Módulo (resto)
# **          Exponente
# LOGICOS
#
# x > 5 and x < 10    # Ambas verdaderas
# x < 5 or x > 10     # Al menos una verdadera
# not x < 5           # Invierte el resultado
#
# COMPARACION
# Devuelven True o False.
# == (igual), != (no igual), < (menor), > (mayor), <= (menor o igual), >= (mayor o igual)
#
# 3.STRING (CADENAS DE TEXTO)
#  - Crear y acceder a strings
# texto = "Hola Mundo"
# primer = texto[0]        # 'H'
# ultimo = texto[-1]       # 'o'
# subcadena = texto[0:4]   # 'Hola'
# invertido = texto[::-1]  # 'odnuM aloH'
#
# METODOS DE STRINGS
#
# METODO                  DESCRIPCION
# .upper()                MAYUS
# .lower()                MINUSCULA
# .strip()                ELIMINA ESPACIOS
# .split()                DIVIDE POR ESPACIOS -- CREAR UN DICC
# .replace(old, new)      REEMPLAZA
# .find(sub)              BUSCA POSICION
# .isalpha()              SOLO LETRAS
# .isdigit()              SOLO NUMEROS
# .count(sub)             CUENTA APARICIONES
#
# 4. ESTRUCTURAS DE CONTROL
# IF/ELSE
#
# edad = int(input("introduce edad"))
#
# if edad >=18:
#     print("mayor de edad")
# elif edad >=13:
#     print("Adolescente")
# else:
#     print("Niño")
#
# Operador Ternario
#
# status = "Mayor" if edad >= 18 else "Menor"
# print(status)
#
# Combinaciones
#
# if edad >= 18 and carnet == True:
#     print("Puedes conducir")
#
# if es_fin_semana or es_festivo:
#     print("¡A descansar!")
#
# if not bloqueado:
#     print("Acceso permitido")
#
#
# 5.BUCLES
#
# WHILE
#
# contador=0
# while contador <5:
#     print(f"Contador: {contador}")
#     contador +=1
#
# FOR
# #RANGE
# for i in range(5): #maximo
#     print(i) #0,1,2,3,4
#
# for i in range(2,5): #minimo / maximo
#     print(i) #2,3,4
#
# for i in range(0,10,2): #minimo / maximo / salto
#     print(i) #0,2,4,6,8
#
# # Con lista
# frutas = ["manzana", "plátano"]
# for fruta in frutas:
#     print(fruta)
#
#
# Break y Continue
# # Break: sale del bucle
# for i in range(10):
#     if i == 5:
#         break
#     print(i)  # 0, 1, 2, 3, 4
#
# # Continue: salta iteración
# for i in range(5):
#     if i == 2:
#         continue
#     print(i)  # 0, 1, 3, 4
#
#
# 6. LISTAS
#
# Crear y Acceder
# frutas = ["manzana", "plátano", "naranja"]
# numeros = [1, 2, 3, 4, 5]
# mixta = [1, "texto", 3.14, True]
#
# primer = frutas[0]      # "manzana"
# ultimo = frutas[-1]     # "naranja"
# rango = frutas[0:2]     # ["manzana", "plátano"]
#
# Método          Descripción
# .append(x)      Añade al final
# .insert(i, x)   Inserta en posición i
# .remove(x)      Elimina primera ocurrencia
# .pop(i)         Elimina posición i
# .sort()         Ordena la lista
# .reverse()      Invierte el orden
# .count(x)       Cuenta apariciones
# len(lista)      Número de elementos
#
#
# 7.DICCIONARIOS
# Crear y Acceder
# persona = {
#     "nombre": "Juan",
#     "edad": 30,
#     "ciudad": "Madrid",
#     "activo": True
# }
#
# nombre = persona["nombre"]           # "Juan"
# edad = persona.get("edad")           # 30
# pais = persona.get("pais", "España")  # Valor por defecto
# Operaciones
# # Añadir
# persona["profesion"] = "Ingeniero"
#
# # Modificar
# persona["edad"] = 31
#
# # Iterar
# for clave, valor in persona.items():
#     print(f"{clave}: {valor}")
#
# # Verificar si existe
# if "edad" in persona:
#     print(persona["edad"])
# Contar Apariciones (Patrón Examen)
# texto = "hola hola mundo hola"
# palabras = texto.split()
# contadores = {}
#
# for palabra in palabras:
#     if palabra in contadores:
#         contadores[palabra] += 1
#     else:
#         contadores[palabra] = 1
#
# print(contadores)  # {'hola': 3, 'mundo': 1}
#
#
# 8. TUPLAS Y CONJUNTOS
# Tuplas
# # Tuplas: inmutables (no se pueden cambiar)
# coordenadas = (10, 20, 30)
# colores = ("rojo", "verde", "azul")
#
# print(coordenadas[0])  # 10
#
# # Retornar múltiples valores
# def obtener_datos():
#     return ("Juan", 30, "Madrid")
#
# nom, edad, ciu = obtener_datos()
# Conjuntos (Sets)
# # Sets: únicos, sin duplicados
# numeros = {1, 2, 3, 3, 4, 4}
# print(numeros)  # {1, 2, 3, 4}
#
# mi_set = {1, 2, 3}
# mi_set.add(4)        # Añade
# mi_set.remove(2)     # Elimina
#
# # Operaciones
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# print(set1 & set2)   # {3} - intersección
# print(set1 | set2)   # {1,2,3,4,5} - unión
#
#
#
# 9. FUNCIONES
# Función Básica
# def saludar():
#     print("¡Hola!")
#
# saludar()  # Llamar
# Con Parámetros
# def sumar(a, b):
#     return a + b
#
# print(sumar(5, 3))  # 8
#
# # Parámetro por defecto
# def multiplicar(a, b=2):
#     return a * b
#
# print(multiplicar(5))      # 10
# print(multiplicar(5, 3))   # 15
# Retornar Múltiples Valores
# def obtener_datos():
#     return "Juan", 30, "Madrid"
#
# nombre, edad, ciudad = obtener_datos()
#
# 10. PROGRAMACIÓN ORIENTADA A OBJETOS
# Clase Básica
# class Persona:
#     def __init__(self, nombre, edad):
#         self.nombre = nombre
#         self.edad = edad
#
#     def presentarse(self):
#         print(f"Hola, soy {self.nombre}")
#
#     #Metodo para controlar lo que devuelves en un string cuando imprimes un objeto
#     def __str__(self):
#         return f"{self.nombre} ({self.edad} años)"
#
# juan = Persona("Juan", 30)
# juan.presentarse()
# print(juan)
#
# Atributos Estáticos
# class Coche:
#     contador = 0  # Atributo estático
#
#     def __init__(self, marca):
#         self.marca = marca
#         Coche.contador += 1
#
# c1 = Coche("Ford")
# c2 = Coche("BMW")
# print(Coche.contador)  # 2
#
# Herencia
# class Animal:
#     def __init__(self, nombre):
#         self.nombre = nombre
#
# class Perro(Animal):
#     def hacer_sonido(self):
#         print(f"{self.nombre} ladra")
#
# perro = Perro("Rex")
# perro.hacer_sonido()
# super() - Llamar Constructor Padre
# class Vehículo:
#     def __init__(self, marca, modelo):
#         self.marca = marca
#         self.modelo = modelo
#
# class Coche(Vehículo):
#     def __init__(self, marca, modelo, puertas):
#         super().__init__(marca, modelo)
#         self.puertas = puertas
#
#
#
# 11. BUENAS PRÁCTICAS Y PATRONES
# Entrada y Salida
# # Input
# edad = int(input("Edad: "))  # Convertir a int
# nombre = input("Nombre: ").strip()  # Quitar espacios
#
# # Output
# print(f"Edad: {edad}")  # f-string (recomendado)
#
# Validación de Datos
# while True:
#     try:
#         edad = int(input("Edad (número): "))
#         if edad < 0:
#             print("No puede ser negativa")
#             continue
#         break
#     except ValueError:
#         print("Debe ser un número")
# Patrones Útiles para Exámenes
# # 1. BUSCAR EN LISTA
# empleados = [emp1, emp2, ...]
# buscado = None
# for emp in empleados:
#     if emp.id == id_buscado:
#         buscado = emp
#         break
#
# # 2. CONTAR
# contador = 0
# for item in lista:
#     if condicion(item):
#         contador += 1
#
# # 3. SUMAR
# total = 0
# for item in lista:
#     total += item.salario
#
# # 4. DICCIONARIO DE CONTEOS
# conteos = {}
# for palabra in palabras:
#     if palabra in conteos:
#         conteos[palabra] += 1
#     else:
#         conteos[palabra] = 1
